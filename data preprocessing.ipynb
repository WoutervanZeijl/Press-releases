# %%
import bs4 as bs
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re
#import edgar
import time
import numpy as np
from textblob import TextBlob
import pandas as pd
import seaborn as sns
from collections import Counter

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt
import time
import re
import nltk
from nltk.corpus import stopwords

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer
from keras.preprocessing import sequence, text
from keras.layers import Input, Embedding

from nltk import word_tokenize
from nltk.corpus import stopwords
from textblob import TextBlob

import datetime as dt
import pandas as pd
import numpy as np
import warnings
import string
import spacy
nlp = spacy.load("en_core_web_sm")

import warnings
warnings.filterwarnings('ignore')

headers = {'User-Agent': "wouter@vanzeijl.nl"}

# %%
abbott_stock = pd.read_csv("datasets/abbott dataset.csv")
accenture_stock = pd.read_csv("datasets/accenture dataset.csv")
adobe_stock = pd.read_csv("datasets/adobe dataset.csv")
alphabet_stock = pd.read_csv("datasets/alphabet dataset.csv")
amazon_stock = pd.read_csv("datasets/amazon dataset.csv")
amd_stock = pd.read_csv("datasets/amd dataset.csv")
amgen_stock = pd.read_csv("datasets/amgen dataset.csv")
analog_stock = pd.read_csv("datasets/analog dataset.csv")
apple_stock = pd.read_csv("datasets/apple dataset.csv")
att_stock = pd.read_csv("datasets/att dataset.csv")
boeing_stock = pd.read_csv("datasets/boeing dataset.csv")
booking_stock = pd.read_csv("datasets/booking dataset.csv")
broadcom_stock = pd.read_csv("datasets/broadcom dataset.csv")
caterpillar_stock = pd.read_csv("datasets/caterpillar dataset.csv")
chevron_stock = pd.read_csv("datasets/chevron dataset.csv")
cisco_stock = pd.read_csv("datasets/cisco dataset.csv")
cola_stock = pd.read_csv("datasets/cola dataset.csv")
deere_stock = pd.read_csv("datasets/deere dataset.csv")
disney_stock = pd.read_csv("datasets/disney dataset.csv")
electric_stock = pd.read_csv("datasets/electric dataset.csv")
elevance_stock = pd.read_csv("datasets/elevance dataset.csv")
exxon_stock = pd.read_csv("datasets/exxon dataset.csv")
home_stock = pd.read_csv("datasets/home dataset.csv")
honeywell_stock = pd.read_csv("datasets/honeywell dataset.csv")
ibm_stock = pd.read_csv("datasets/ibm dataset.csv")
intel_stock = pd.read_csv("datasets/intel dataset.csv")
lockhead_stock = pd.read_csv("datasets/lockhead dataset.csv")
materials_stock = pd.read_csv("datasets/materials dataset.csv")
mcdonalds_stock = pd.read_csv("datasets/mcdonalds dataset.csv")
medtronic_stock = pd.read_csv("datasets/medtronic dataset.csv")
meta_stock = pd.read_csv("datasets/meta dataset.csv")
microsoft_stock = pd.read_csv("datasets/microsoft dataset.csv")
nike_stock = pd.read_csv("datasets/nike dataset.csv")
nvidia_stock = pd.read_csv("datasets/nvidia dataset.csv")
oracle_stock = pd.read_csv("datasets/oracle dataset.csv")
pfizer_stock = pd.read_csv("datasets/pfizer dataset.csv")
philips_stock = pd.read_csv("datasets/philips dataset.csv")
prologis_stock = pd.read_csv("datasets/prologis dataset.csv")
salesforce_stock = pd.read_csv("datasets/salesforce dataset.csv")
service_stock = pd.read_csv("datasets/service dataset.csv")
starbucks_stock = pd.read_csv("datasets/starbucks dataset.csv")
stryker_stock = pd.read_csv("datasets/stryker dataset.csv")
tesla_stock = pd.read_csv("datasets/tesla dataset.csv")
thermo_stock = pd.read_csv("datasets/thermo dataset.csv")
union_stock = pd.read_csv("datasets/union dataset.csv")
united_stock = pd.read_csv("datasets/united health dataset.csv")
ups_stock = pd.read_csv("datasets/ups dataset.csv")
verizon_stock = pd.read_csv("datasets/verizon dataset.csv")
visa_stock = pd.read_csv("datasets/visa dataset.csv")
wallmart_stock = pd.read_csv("datasets/wallmart dataset.csv")

# %%
frames = [abbott_stock, accenture_stock, adobe_stock, alphabet_stock, amazon_stock, amd_stock, amgen_stock, analog_stock,
          apple_stock, att_stock, boeing_stock, booking_stock,  broadcom_stock, caterpillar_stock, chevron_stock, 
          cisco_stock, cola_stock, deere_stock, disney_stock, electric_stock, elevance_stock, exxon_stock, home_stock, 
          honeywell_stock, ibm_stock, intel_stock, lockhead_stock, materials_stock, mcdonalds_stock, meta_stock, medtronic_stock, 
          microsoft_stock, nike_stock, nvidia_stock, oracle_stock, pfizer_stock, philips_stock, prologis_stock, salesforce_stock, 
          service_stock, starbucks_stock, stryker_stock, tesla_stock, thermo_stock, union_stock,
          united_stock, ups_stock, verizon_stock, visa_stock, wallmart_stock]

result = pd.concat(frames)

#result.dropna(subset=['press release'], inplace=True)

# %%
# Out:
#            Date   Adj Close    Volume  \
# 100  2023-05-01  102.000000  92188800
# 0    2015-01-01   72.944267  54792200
# 1    2015-02-01   78.152679  41496100
# 2    2015-03-01   81.329834  68503900
# 3    2015-04-01   80.427017  48841600
# 4    2015-05-01   84.261475  39458400
# 5    2015-06-01   84.910706  49597500
# 6    2015-07-01   90.464394  48475700
# 7    2015-08-01   82.708534  56966300
# 8    2015-09-01   86.209198  60092500
# 9    2015-10-01   94.052780  55509800
# 10   2015-11-01   95.081055  46891900
# 11   2015-12-01   92.668999  54959900
# 12   2016-01-01   93.591248  66081200
# 13   2016-02-01   88.909035  72193500
# 14   2016-03-01  102.334946  68422700
# 15   2016-04-01  100.135719  49572000
# 16   2016-05-01  106.525139  37905300
# 17   2016-06-01  101.439301  50791400
# 18   2016-07-01  101.009499  43799800
# 19   2016-08-01  102.970428  42291400
# 20   2016-09-01  109.390404  58695000
# 21   2016-10-01  104.080696  50003000
# 22   2016-11-01  108.049408  54957500
# 23   2016-12-01  105.968597  49415000
# 24   2017-01-01  103.019241  52904600
# 25   2017-02-01  110.826859  38174000
# 26   2017-03-01  108.456543  65634500
# 27   2017-04-01  109.741219  42332600
# 28   2017-05-01  113.777435  40493000
# 29   2017-06-01  113.055305  56432600
# 30   2017-07-01  117.753761  33694900
# 31   2017-08-01  119.527100  34604900
# 32   2017-09-01  123.466858  50820700
# 33   2017-10-01  130.130600  41387500
# 34   2017-11-01  136.605606  34120000
# 35   2017-12-01  141.294174  40816400
# 36   2018-01-01  148.317856  42247000
# 37   2018-02-01  148.603958  43864100
# 38   2018-03-01  141.672623  66273100
# 39   2018-04-01  139.549835  42164300
# 40   2018-05-01  145.008408  37186500
# 41   2018-06-01  152.317459  57789200
# 42   2018-07-01  148.351044  42665600
# 43   2018-08-01  157.419907  37640800
# 44   2018-09-01  158.472046  40698200
# 45   2018-10-01  146.758850  53970000
# 46   2018-11-01  154.583496  47618200
# 47   2018-12-01  132.493378  58259200
# 48   2019-01-01  144.276016  43567200
#
#                                          press release  Price change 12mo  \
# 100                                                NaN                NaN
# 0                                                  NaN                NaN
# 1                                                  NaN                NaN
# 2                                                  NaN                NaN
# 3                                                  NaN                NaN
# 4                                                  NaN                NaN
# 5                                                  NaN                NaN
# 6                                                  NaN                NaN
# 7                                                  NaN                NaN
# 8                                                  NaN                NaN
# 9                                                  NaN                NaN
# 10                                                 NaN                NaN
# 11                                                 NaN                NaN
# 12                                                 NaN                NaN
# 13                                                 NaN                NaN
# 14                                                 NaN                NaN
# 15                                                 NaN                NaN
# 16                                                 NaN                NaN
# 17                                                 NaN                NaN
# 18                                                 NaN                NaN
# 19                                                 NaN                NaN
# 20                                                 NaN                NaN
# 21                                                 NaN                NaN
# 22                                                 NaN                NaN
# 23                                                 NaN                NaN
# 24                                                 NaN                NaN
# 25                                                 NaN                NaN
# 26                                                 NaN                NaN
# 27                                                 NaN                NaN
# 28                                                 NaN                NaN
# 29                                                 NaN                NaN
# 30                                                 NaN                NaN
# 31                                                 NaN                NaN
# 32                                                 NaN                NaN
# 33                                                 NaN                NaN
# 34                                                 NaN                NaN
# 35                                                 NaN                NaN
# 36                                                 NaN                NaN
# 37                                                 NaN                NaN
# 38                                                 NaN                NaN
# 39                                                 NaN                NaN
# 40                                                 NaN                NaN
# 41                                                 NaN                NaN
# 42                                                 NaN                NaN
# 43                                                 NaN                NaN
# 44                                                 NaN                NaN
# 45   We are very pleased with our outstanding finan...          21.942078
# 46                                                 NaN                NaN
# 47                                                 NaN                NaN
# 48                                                 NaN                NaN
#
#      Price change 8mo  Price change 4mo
# 100               NaN               NaN
# 0                 NaN               NaN
# 1                 NaN               NaN
# 2                 NaN               NaN
# 3                 NaN               NaN
# 4                 NaN               NaN
# 5                 NaN               NaN
# 6                 NaN               NaN
# 7                 NaN               NaN
# 8                 NaN               NaN
# 9                 NaN               NaN
# 10                NaN               NaN
# 11                NaN               NaN
# 12                NaN               NaN
# 13                NaN               NaN
# 14                NaN               NaN
# 15                NaN               NaN
# 16                NaN               NaN
# 17                NaN               NaN
# 18                NaN               NaN
# 19                NaN               NaN
# 20                NaN               NaN
# 21                NaN               NaN
# 22                NaN               NaN
# 23                NaN               NaN
# 24                NaN               NaN
# 25                NaN               NaN
# 26                NaN               NaN
# 27                NaN               NaN
# 28                NaN               NaN
# 29                NaN               NaN
# 30                NaN               NaN
# 31                NaN               NaN
# 32                NaN               NaN
# 33                NaN               NaN
# 34                NaN               NaN
# 35                NaN               NaN
# 36                NaN               NaN
# 37                NaN               NaN
# 38                NaN               NaN
# 39                NaN               NaN
# 40                NaN               NaN
# 41                NaN               NaN
# 42                NaN               NaN
# 43                NaN               NaN
# 44                NaN               NaN
# 45          18.630051         -2.482834
# 46                NaN               NaN
# 47                NaN               NaN
# 48                NaN               NaN

# %%
def getSIA(text):
    sia = SentimentIntensityAnalyzer()
    sentiment = sia.polarity_scores(text)
    return sentiment

# %%
compound = []
neg = []
pos = []
neu = []
SIA = 0

for i in range(0, len(result['press release'])):
    SIA = getSIA(result['press release'].iloc[i])
    compound.append(SIA['compound'])
    neg.append(SIA['neg'])
    neu.append(SIA['neu'])
    pos.append(SIA['pos'])

# %%
result['Compound'] = compound
result['Negative'] = neg
result['Neutral'] = neu
result['Positive'] = pos

# %%
result['polarity'] = np.nan
result['subjectivity'] = np.nan

for i in range(0, len(result['press release'])):
    senti = TextBlob(result['press release'].iloc[i]).sentiment.polarity
    subj = TextBlob(result['press release'].iloc[i]).sentiment.subjectivity
    result['polarity'].iloc[i] = senti
    result['subjectivity'].iloc[i] = subj

# %%
result
# Out:
#           Date   Adj Close     Volume  \
# 36  2018-01-01   56.711449  156001900
# 48  2019-01-01   67.803299  157850300
# 60  2020-01-01   82.301605  119657000
# 72  2021-01-01  118.568031  108930500
# 84  2022-01-01  124.170898  155539600
# ..         ...         ...        ...
# 37  2018-02-01   81.499840  307532700
# 49  2019-02-01   91.758194  166799500
# 61  2020-02-01  101.834824  132414100
# 73  2021-02-01  124.918640  184999800
# 85  2022-02-01  132.023560  162588100
#
#                                         press release  Price change 12mo  \
# 36  2017 was a great year for us — we performed we...           5.133094
# 48  2018 was another outstanding year for Abbott. ...          12.457611
# 60  Our focus on organic growth is driving top-tie...          22.371323
# 72  Despite challenging conditions, we achieved do...           4.067505
# 84  2021 was an outstanding year for Abbott. We ac...         -22.969223
# ..                                                ...                ...
# 37  We have good momentum in the business with sol...          -7.329239
# 49  We had a good year, and I want to thank our as...         -16.516945
# 61  We thank our associates for another good year....         -33.246933
# 73  We completed a strong year and a strong Q4 tha...         -11.647019
# 85  We had another strong quarter to finish off a ...         -10.716949
#
#     Price change 8mo  Price change 4mo  Compound  Negative  Neutral  Positive  \
# 36         -0.532227         -3.423134    0.8882     0.000    0.723     0.277
# 48         11.014770          6.456009    0.9217     0.000    0.725     0.275
# 60          4.783768          5.044571    0.8932     0.000    0.592     0.408
# 72         -6.490669         -2.903244    0.8103     0.031    0.757     0.212
# 84        -17.527900        -13.209739    0.8360     0.000    0.806     0.194
# ..               ...               ...       ...       ...      ...       ...
# 37        -10.949623          2.993950    0.9758     0.000    0.676     0.324
# 49        -18.641411        -11.757950    0.9913     0.000    0.635     0.365
# 61        -31.088043        -12.444900    0.9945     0.029    0.751     0.220
# 73        -20.448700        -11.773529    0.9887     0.009    0.810     0.182
# 85         -8.658691         12.372200    0.8591     0.029    0.772     0.199
#
#     polarity  subjectivity
# 36  0.505273      0.704909
# 48  0.362500      0.731250
# 60  0.671667      0.756667
# 72  0.384091      0.638636
# 84  0.307273      0.579242
# ..       ...           ...
# 37  0.325000      0.377778
# 49  0.411970      0.587121
# 61  0.228437      0.476852
# 73  0.285088      0.561404
# 85  0.388889      0.755556
#
# [248 rows x 13 columns]

# %%
stop_words = stopwords.words('english')
punctuation = string.punctuation

# %%
result["text length"] = result["press release"].apply(len)

result['char_count'] = result['press release'].apply(len)
result['word_count'] = result['press release'].apply(lambda x: len(x.split()))
result['word_density'] = result['char_count'] / (result['word_count']+1)
result['punctuation_count'] = result['press release'].apply(lambda x: len("".join(_ for _ in x if _ in punctuation))) 
result['title_word_count'] = result['press release'].apply(lambda x: len([wrd for wrd in x.split() if wrd.istitle()]))
result['upper_case_word_count'] = result['press release'].apply(lambda x: len([wrd for wrd in x.split() if wrd.isupper()]))
result['stopword_count'] = result['press release'].apply(lambda x: len([wrd for wrd in x.split() if wrd.lower() in stop_words]))

# %%
nltk.download('averaged_perceptron_tagger')
pos_dic = {
    'noun' : ['NN','NNS','NNP','NNPS'],
    'pron' : ['PRP','PRP$','WP','WP$'],
    'verb' : ['VB','VBD','VBG','VBN','VBP','VBZ'],
    'adj' :  ['JJ','JJR','JJS'],
    'adv' : ['RB','RBR','RBS','WRB']
}

# function to check and get the part of speech tag count of a words in a given sentence
def pos_check(x, flag):
    cnt = 0
    try:
        wiki = TextBlob(x)
        for tup in wiki.tags:
            ppo = list(tup)[1]
            if ppo in pos_dic[flag]:
                cnt += 1
    except:
        pass
    return cnt

result['noun_count'] = result['press release'].apply(lambda x: pos_check(x, 'noun'))
result['verb_count'] = result['press release'].apply(lambda x: pos_check(x, 'verb'))
result['adj_count'] = result['press release'].apply(lambda x: pos_check(x, 'adj'))
result['adv_count'] = result['press release'].apply(lambda x: pos_check(x, 'adv'))
result['pron_count'] = result['press release'].apply(lambda x: pos_check(x, 'pron'))
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Wouter\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# top words
result["top_words"] = np.nan

from collections import Counter

def word_count(text):
    doc = nlp(text)
    words = [token.text for token in doc if not token.is_stop and not token.is_punct]
    
    word_freq = Counter(words)
    common_words = word_freq.most_common(10)
    return common_words

for i in range(len(result["press release"])):
    top_words = word_count(result['press release'].iloc[i])
    result["top_words"].iloc[i] = top_words

# %%
result["top_words"]
# Out:
# 36    [(2017, 1), (great, 1), (year, 1), (performed,...
# 48    [(year, 2), (2018, 1), (outstanding, 1), (Abbo...
# 60    [(growth, 2), (focus, 1), (organic, 1), (drivi...
# 72    [(EPS, 2), (growth, 2), (Despite, 1), (challen...
# 84    [(year, 2), (EPS, 2), (2021, 1), (outstanding,...
#                             ...
# 37    [(business, 2), (making, 2), (work, 2), (custo...
# 49    [(want, 2), (work, 2), (customers, 2), (delive...
# 61    [(strong, 5), (quarter, 5), (sales, 5), (U.S.,...
# 73    [(strong, 4), (associates, 3), (customers, 3),...
# 85    [(strong, 2), (business, 2), (quarter, 1), (fi...
# Name: top_words, Length: 248, dtype: object

# %%
to_append = []

for i in result['Price change 12mo']:
    if i >= 0:
        to_append.append(1)
    else:
        to_append.append(-1)
        
result['Price change sign long'] = to_append

# %%
to_append = []

for i in result['Price change 8mo']:
    if i >= 0:
        to_append.append(1)
    else:
        to_append.append(-1)
        
result['Price change sign mid'] = to_append

# %%
to_append = []

for i in result['Price change 4mo']:
    if i >= 0:
        to_append.append(1)
    else:
        to_append.append(-1)
        
result['Price change sign short'] = to_append

# %%
ones = len(result[result['Price change sign long']==1])
minus = len(result[result['Price change sign long']==-1])

fig, ax = plt.subplots(figsize=(6,6))
plt.pie(x=[ones, minus], labels=['Upwards','Downwards'], shadow=True, autopct='%1.1f%%')
plt.title('Class Distribution', fontsize=18)
plt.show()

result.describe()
# Out:
#          Adj Close        Volume  Price change 12mo  Price change 8mo  \
# count   248.000000  2.480000e+02         248.000000        248.000000
# mean    188.598811  3.394098e+08          17.623202          6.964820
# std     284.502164  5.189971e+08          72.128091         74.073769
# min      13.740000  7.179000e+06        -440.849854       -812.919922
# 25%      70.635208  6.225920e+07          -4.581470         -7.209635
# 50%     122.636677  1.382164e+08           9.799576          4.883839
# 75%     203.677041  3.791968e+08          35.436981         22.120811
# max    2456.129883  3.158994e+09         454.900024        429.540161
#
#        Price change 4mo    Compound    Negative     Neutral    Positive  \
# count        248.000000  248.000000  248.000000  248.000000  248.000000
# mean           4.290364    0.947066    0.012302    0.759065    0.228633
# std           47.943331    0.092223    0.019032    0.060063    0.063084
# min         -212.569824   -0.077200    0.000000    0.591000    0.097000
# 25%           -8.710438    0.944000    0.000000    0.717000    0.186750
# 50%            2.193904    0.969350    0.000000    0.757500    0.222000
# 75%           16.623924    0.986675    0.019000    0.800250    0.276000
# max          417.220093    0.998300    0.121000    0.903000    0.409000
#
#          polarity  ...  upper_case_word_count  stopword_count  noun_count  \
# count  248.000000  ...             248.000000      248.000000  248.000000
# mean     0.270640  ...               1.790323       45.258065   37.737903
# std      0.130901  ...               2.319689       26.893062   24.992790
# min     -0.138889  ...               0.000000        6.000000    5.000000
# 25%      0.180652  ...               0.000000       27.000000   22.000000
# 50%      0.254232  ...               1.000000       39.000000   32.000000
# 75%      0.346239  ...               2.000000       54.250000   45.000000
# max      0.733333  ...              14.000000      197.000000  185.000000
#
#        verb_count   adj_count   adv_count  pron_count  Price change sign long  \
# count  248.000000  248.000000  248.000000  248.000000              248.000000
# mean    17.455645   13.947581    3.899194    9.697581                0.354839
# std      9.524635    8.718336    3.584989    5.410411                0.936818
# min      4.000000    1.000000    0.000000    2.000000               -1.000000
# 25%     11.000000    8.000000    2.000000    6.000000               -1.000000
# 50%     16.000000   12.000000    3.000000    8.000000                1.000000
# 75%     21.000000   17.250000    5.000000   13.000000                1.000000
# max     62.000000   53.000000   21.000000   32.000000                1.000000
#
#        Price change sign mid  Price change sign short
# count             248.000000               248.000000
# mean                0.225806                 0.169355
# std                 0.976142                 0.987548
# min                -1.000000                -1.000000
# 25%                -1.000000                -1.000000
# 50%                 1.000000                 1.000000
# 75%                 1.000000                 1.000000
# max                 1.000000                 1.000000
#
# [8 rows x 27 columns]

# %%
f, ax = plt.subplots(figsize=(12, 11))
sns.heatmap(result.corr(), vmax=.8, square=True);

# %%
result = result.drop(columns=['Price change 12mo', 'Price change 8mo', 'Price change 4mo', 'Price change sign mid', 'Price change sign short'])

# %%
corrmat = result.corr()
k = 10 
cols = corrmat.nlargest(k, 'Price change sign long')['Price change sign long'].index
cm = np.corrcoef(result[cols].values.T)
sns.set(font_scale=1.0)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
corrmat['Price change sign long'].sort_values(ascending=False)
# Out:
# Price change sign long    1.000000
# polarity                  0.112370
# subjectivity              0.073096
# Positive                  0.062566
# Negative                  0.046865
# word_density              0.028198
# verb_count                0.001317
# stopword_count           -0.004614
# Compound                 -0.006527
# pron_count               -0.006699
# Adj Close                -0.018493
# Volume                   -0.020415
# text length              -0.027876
# char_count               -0.027876
# word_count               -0.030271
# adj_count                -0.037865
# adv_count                -0.053197
# noun_count               -0.054630
# Neutral                  -0.080419
# upper_case_word_count    -0.092310
# title_word_count         -0.092341
# punctuation_count        -0.095700
# Name: Price change sign long, dtype: float64

# %%
sns.set()
cols = ['Price change sign long', 'polarity', 'punctuation_count', 'noun_count', 'upper_case_word_count', 'title_word_count']
sns.pairplot(result[cols], size = 2.5)
plt.show();

# %% [markdown]
# # top words for long sign

# %%
top_up_words_long = {}
for i in result[result['Price change sign long'] == 1]['top_words']:
    for j in i:
        if j[0] in top_up_words_long:
            top_up_words_long[j[0]] += j[1]
        else:
            top_up_words_long[j[0]] = j[1]
            
top_up_words_long = sorted(top_up_words_long.items(), key=lambda x:x[1], reverse=True)
print(top_up_words_long)
# Out:
# [('year', 189), ('growth', 146), ('strong', 94), ('$', 72), ('quarter', 63), ('customers', 56), ('fiscal', 46), ('record', 45), ('billion', 44), ('revenue', 44), ('performance', 40), ('business', 39), ('2020', 35), ('cash', 34), ('results', 29), ('2018', 27), ('cloud', 24), ('delivered', 23), ('2019', 23), ('fourth', 22), ('Q4', 21), ('continued', 21), ('2017', 20), ('sales', 19), ('2021', 19), ('term', 17), ('Honeywell', 17), ('long', 16), ('flow', 16), ('capital', 16), ('world', 16), ('new', 15), ('earnings', 15), ('Apple', 15), ('company', 15), ('Pfizer', 15), ('customer', 14), ('Affiliates', 14), ('continue', 13), ('said', 13), ('Microsoft', 13), ('product', 12), ('shareholders', 12), ('investments', 12), ('operating', 12), ('demand', 12), ('great', 11), ('AI', 11), ('products', 11), ('financial', 11), ('global', 11), ('pandemic', 11), ('NVIDIA', 11), ('challenging', 10), ('percent', 10), ('free', 10), ('digital', 10), ('services', 9), ('significant', 9), ('Alexa', 9), ('share', 9), ('AMG', 9), ('pleased', 9), ('employees', 9), ('finish', 9), ('drive', 9), ('net', 9), ('adjusted', 9), ('McDonald', 9), ('Oracle', 9), ('volume', 9), ('focus', 8), ('clients', 8), ('2022', 8), ('cost', 8), ('Amazon', 8), ('solid', 8), ('end', 8), ('time', 8), ('impact', 8), ('COVID-19', 8), ('healthcare', 8), ('Starbucks', 8), ('Visa', 8), ('outstanding', 7), ('achieved', 7), ('help', 7), ('Adobe', 7), ('Prime', 7), ('markets', 7), ('Broadcom', 7), ('dividend', 7), ('Deere', 7), ('NIKE', 7), ('excellent', 7), ('work', 7), ('ServiceNow', 7), ('service', 7), ('organic', 6), ('driving', 6), ('momentum', 6), ('value', 6), ('constant', 6), ('portfolio', 6), ('strategic', 6), ('environment', 6), ('margin', 6), ('focused', 6), ('solutions', 6), ('experience', 6), ('hybrid', 6), ('currency', 6), ('deliver', 6), ('consumers', 6), ('finished', 6), ('strategy', 6), ('5', 6), ('G', 6), ('exceeded', 5), ('businesses', 5), ('delivering', 5), ('including', 5), ('investment', 5), ('strength', 5), ('grow', 5), ('commercial', 5), ('enterprise', 5), ('software', 5), ('infrastructure', 5), ('team', 5), ('resilience', 5), ('system', 5), ('health', 5), ('ability', 5), ('IQOS', 5), ('operational', 5), ('better', 5), ('expected', 5), ('good', 4), ('EPS', 4), ('proud', 4), ('market', 4), ('people', 4), ('communities', 4), ('U.S.', 4), ('marked', 4), ('generated', 4), ('areas', 4), ('ADI', 4), ('high', 4), ('concluded', 4), ('September', 4), ('goal', 4), ('investing', 4), ('Enterprise', 4), ('completed', 4), ('transformation', 4), ('John', 4), ('improved', 4), ('GE', 4), ('Anthem', 4), ('greater', 4), ('years', 4), ('associates', 4), ('spin', 4), ('growing', 4), ('platform', 4), ('Velocity', 4), ('Growth', 4), ('Plan', 4), ('intelligent', 4), ('partnerships', 4), ('chief', 4), ('executive', 4), ('officer', 4), ('computing', 4), ('information', 4), ('Upjohn', 4), ('best', 4), ('recovery', 4), ('men', 4), ('pricing', 4), ('productivity', 4), ('network', 4), ('Verizon', 4), ('conditions', 3), ('double', 3), ('digit', 3), ('demonstrate', 3), ('unprecedented', 3), ('structure', 3), ('positive', 3), ('delivery', 3), ('day', 3), ('invention', 3), ('milestone', 3), ('successfully', 3), ('significantly', 3), ('accelerated', 3), ('annual', 3), ('client', 3), ('led', 3), ('opportunity', 3), ('travel', 3), ('Symantec', 3), ('Security', 3), ('driven', 3), ('highest', 3), ('guidance', 3), ('uncertainty', 3), ('higher', 3), ('result', 3), ('launch', 3), ('IngenioRx', 3), ('industry', 3), ('smoke', 3), ('Intel', 3), ('look', 3), ('national', 3), ('platforms', 3), ('Applied', 3), ('restaurants', 3), ('grew', 3), ('Cloud', 3), ('database', 3), ('Autonomous', 3), ('Database', 3), ('decisions', 3), ('Liberty', 3), ('expectations', 3), ('women', 3), ('highly', 2), ('set', 2), ('Despite', 2), ('testament', 2), ('line', 2), ('Marketo', 2), ('phenomenal', 2), ('capped', 2), ('FY20', 2), ('Google', 2), ('opportunities', 2), ('revenues', 2), ('far', 2), ('developers', 2), ('Echo', 2), ('compare ...

# %%
top_down_words_long = {}
for i in result[result['Price change sign long'] == -1]['top_words']:
    for j in i:
        if j[0] in top_down_words_long:
            top_down_words_long[j[0]] += j[1]
        else:
            top_down_words_long[j[0]] = j[1]
            
top_down_words_long = sorted(top_down_words_long.items(), key=lambda x:x[1], reverse=True)

#normalize 116 postive and 27 negative = 168/80 = 2.1
top_down_words_long_new = []
for key, value in top_down_words_long:
    value = value * 2.1
    top_down_words_long_new.append(tuple([key, int(value)])) 

print(top_down_words_long_new)
# Out:
# [('growth', 210), ('year', 201), ('strong', 136), ('quarter', 100), ('$', 65), ('performance', 63), ('business', 63), ('revenue', 50), ('customers', 42), ('fiscal', 35), ('billion', 35), ('2021', 33), ('fourth', 33), ('sales', 33), ('cloud', 33), ('businesses', 29), ('Prime', 29), ('Oracle', 29), ('new', 27), ('delivered', 27), ('percent', 25), ('financial', 25), ('Q4', 25), ('2017', 25), ('2019', 25), ('term', 21), ('U.S.', 21), ('NVIDIA', 21), ('results', 18), ('value', 18), ('Amazon', 18), ('Apple', 18), ('like', 16), ('excellent', 16), ('cash', 16), ('investments', 16), ('outstanding', 14), ('record', 14), ('2018', 14), ('strategy', 14), ('company', 14), ('continue', 14), ('high', 14), ('products', 14), ('MySQL', 14), ('great', 12), ('product', 12), ('million', 12), ('delivering', 12), ('commercial', 12), ('2022', 12), ('making', 12), ('solid', 12), ('Disney+', 12), ('supply', 12), ('AI', 12), ('said', 12), ('NIKE', 12), ('EPS', 10), ('people', 10), ('drive', 10), ('Affiliates', 10), ('long', 10), ('momentum', 10), ('work', 10), ('flow', 10), ('grew', 10), ('good', 10), ('free', 10), ('applications', 10), ('margin', 10), ('Database', 10), ('tobacco', 10), ('want', 10), ('achieved', 8), ('ongoing', 8), ('Rings', 8), ('members', 8), ('price', 8), ('AMG', 8), ('Boeing', 8), ('shareholders', 8), ('returning', 8), ('end', 8), ('increase', 8), ('construction', 8), ('equipment', 8), ('Disney', 8), ('GE', 8), ('strengthen', 8), ('portfolio', 8), ('Honeywell', 8), ('expectations', 8), ('operating', 8), ('Fusion', 8), ('earnings', 8), ('IQOS', 8), ('eCommerce', 8), ('associates', 8), ('clients', 6), ('progress', 6), ('Adobe', 6), ('investment', 6), ('areas', 6), ('iPhone', 6), ('September', 6), ('positive', 6), ('HBO', 6), ('focused', 6), ('737', 6), ('MAX', 6), ('brands', 6), ('line', 6), ('travel', 6), ('significantly', 6), ('Deere', 6), ('IBM', 6), ('store', 6), ('Intel', 6), ('finish', 6), ('completed', 6), ('demand', 6), ('chain', 6), ('digital', 6), ('platform', 6), ('ERP', 6), ('smoke', 6), ('reduced', 6), ('risk', 6), ('adjusted', 6), ('global', 6), ('Starbucks', 6), ('Verizon', 6), ('started', 6), ('stores', 6), ('Walmart', 6), ('helped', 4), ('Cloud', 4), ('AMD', 4), ('data', 4), ('center', 4), ('range', 4), ('strongest', 4), ('impact', 4), ('broadband', 4), ('postpaid', 4), ('phone', 4), ('net', 4), ('adds', 4), ('ended', 4), ('services', 4), ('team', 4), ('focus', 4), ('driving', 4), ('programs', 4), ('production', 4), ('returned', 4), ('recovery', 4), ('customer', 4), ('operational', 4), ('excellence', 4), ('early', 4), ('profitable', 4), ('implementing', 4), ('dividend', 4), ('emission', 4), ('gas', 4), ('operations', 4), ('order', 4), ('transformation', 4), ('markets', 4), ('farm', 4), ('reflect', 4), ('streaming', 4), ('DTC', 4), ('best', 4), ('direct', 4), ('subscriptions', 4), ('total', 4), ('execution', 4), ('low', 4), ('guidance', 4), ('committed', 4), ('strategic', 4), ('position', 4), ('blockchain', 4), ('acquisition', 4), ('share', 4), ('expanded', 4), ('exceeded', 4), ('capping', 4), ('quarterly', 4), ('exceptional', 4), ('semiconductor', 4), ('orders', 4), ('Semiconductor', 4), ('Systems', 4), ('Demand', 4), ('continued', 4), ('ahead', 4), ('reported', 4), ('chief', 4), ('executive', 4), ('officer', 4), ('Microsoft', 4), ('consumer', 4), ('GPU', 4), ('computing', 4), ('non', 4), ('GAAP', 4), ('capital', 4), ('allocation', 4), ('pipeline', 4), ('structure', 4), ('currency', 4), ('robust', 4), ('inventory', 4), ('heated', 4), ('volume', 4), ('combustible', 4), ('diluted', 4), ('digit', 4), ('pandemic', 4), ('proven', 4), ('FY23', 4), ('comparable', 4), ('partners', 4), ('exceed', 4), ('Reinvention', 4), ('2023', 4), ('organic', 4), ('meet', 4), ('network', 4), ('significant', 4), ('thank', 4), ('deliver', 4), ('serve', 4), ('McMillon', 4), ('capabilities', 4), ('Abbott', 2), ('40', 2), ('exceeding', 2), ('proud', 2), ('resulted', 2), ('annual', 2), ('profitability', 2), ('ADI', 2), ('profits', 2), ('tax', 2),  ...

# %%
top_down_words_long_dict = {}

for i in top_down_words_long_new:
    if i[0] in top_down_words_long_dict:
        top_down_words_long_dict[i[0]] += i[1]
    else:
        top_down_words_long_dict[i[0]] = i[1]

# %%
# difference between list where the number followed by the word is the times it occurs more in POSTIVE 1
difference_list_long = []
for i in top_up_words_long[:25]:
    if i[0] in top_down_words_long_dict:
        difference = i[1] / top_down_words_long_dict[i[0]]
        difference_list_long.append(tuple([i[0], difference]))

# %%
difference_list_long
# Out:
# [('year', 0.9402985074626866),
#  ('growth', 0.6952380952380952),
#  ('strong', 0.6911764705882353),
#  ('$', 1.1076923076923078),
#  ('quarter', 0.63),
#  ('customers', 1.3333333333333333),
#  ('fiscal', 1.3142857142857143),
#  ('record', 3.2142857142857144),
#  ('billion', 1.2571428571428571),
#  ('revenue', 0.88),
#  ('performance', 0.6349206349206349),
#  ('business', 0.6190476190476191),
#  ('cash', 2.125),
#  ('results', 1.6111111111111112),
#  ('2018', 1.9285714285714286),
#  ('cloud', 0.7272727272727273),
#  ('delivered', 0.8518518518518519),
#  ('2019', 0.92),
#  ('fourth', 0.6666666666666666),
#  ('Q4', 0.84),
#  ('continued', 5.25),
#  ('2017', 0.8),
#  ('sales', 0.5757575757575758),
#  ('2021', 0.5757575757575758)]

# %%
difference_dict = {}

for i in difference_list_long:
    difference_dict[i[0]] = i[1]

# %%
difference_dict
# Out:
# {'year': 0.9402985074626866,
#  'growth': 0.6952380952380952,
#  'strong': 0.6911764705882353,
#  '$': 1.1076923076923078,
#  'quarter': 0.63,
#  'customers': 1.3333333333333333,
#  'fiscal': 1.3142857142857143,
#  'record': 3.2142857142857144,
#  'billion': 1.2571428571428571,
#  'revenue': 0.88,
#  'performance': 0.6349206349206349,
#  'business': 0.6190476190476191,
#  'cash': 2.125,
#  'results': 1.6111111111111112,
#  '2018': 1.9285714285714286,
#  'cloud': 0.7272727272727273,
#  'delivered': 0.8518518518518519,
#  '2019': 0.92,
#  'fourth': 0.6666666666666666,
#  'Q4': 0.84,
#  'continued': 5.25,
#  '2017': 0.8,
#  'sales': 0.5757575757575758,
#  '2021': 0.5757575757575758}

# %%
'year' in difference_list_long
# Out:
# False

# %%
result["word_calculation"] = np.nan
for i in range(len(result["press release"])):
    count = 1
    doc = nlp(result["press release"].iloc[i])
    for word in doc:
        for j in difference_list_long:
            if str(word) == j[0]:
                count = count * j[1]
    result["word_calculation"].iloc[i] = count

# %%
difference_list_long.sort(key=lambda a: a[1])

# %%
difference_list_long
# Out:
# [('sales', 0.5757575757575758),
#  ('business', 0.6190476190476191),
#  ('quarter', 0.63),
#  ('performance', 0.6349206349206349),
#  ('fourth', 0.6666666666666666),
#  ('strong', 0.6911764705882353),
#  ('growth', 0.6952380952380952),
#  ('cloud', 0.7272727272727273),
#  ('delivered', 0.8518518518518519),
#  ('revenue', 0.88),
#  ('year', 0.9402985074626866),
#  ('billion', 1.2571428571428571),
#  ('fiscal', 1.3142857142857143),
#  ('customers', 1.3333333333333333),
#  ('results', 1.6111111111111112),
#  ('cash', 2.125),
#  ('record', 3.2142857142857144),
#  ('continued', 5.25)]

# %%
#difference_list_long.remove(('2021', 0.5757575757575758))
#difference_list_long.remove(('2017', 0.8))
#difference_list_long.remove(('Q4', 0.84))
#difference_list_long.remove(('2019', 0.92))
#difference_list_long.remove(('Q4', 21))
#difference_list_long.remove(('$', 1.1076923076923078))
#difference_list_long.remove(('2018', 1.9285714285714286))
difference_list_long.remove(('2018', 1.9285714285714286))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 8
#       1 #difference_list_long.remove(('2021', 0.5757575757575758))
#       2 #difference_list_long.remove(('2017', 0.8))
#       3 #difference_list_long.remove(('Q4', 0.84))
#    (...)
#       6 #difference_list_long.remove(('$', 1.1076923076923078))
#       7 #difference_list_long.remove(('2018', 1.9285714285714286))
# ----> 8 difference_list_long.remove(('2018', 1.9285714285714286))
#
# ValueError: list.remove(x): x not in list

# %%
words = []
value = []
for i in difference_list_long:
    words.append(i[0])
    value.append(i[1])

#country = ['A', 'B', 'C', 'D', 'E']
#gdp_per_capita = [45000, 42000, 52000, 49000, 47000]

#colors = ['green', 'blue', 'purple', 'brown', 'teal']
plt.barh(words, value)
plt.title('Chance of occurence of word for a positive stock', fontsize=14)
plt.xlabel('Chance', fontsize=14)
plt.ylabel('Word', fontsize=14)
plt.xticks(rotation = 90)
plt.grid(True)
plt.show()

# %%
words = []
value = []
for i in top_up_words_long[:25]:
    words.append(i[0])
    value.append(i[1])

#country = ['A', 'B', 'C', 'D', 'E']
#gdp_per_capita = [45000, 42000, 52000, 49000, 47000]

#colors = ['green', 'blue', 'purple', 'brown', 'teal']
plt.bar(words, value)
plt.title('Chance of occurence of word for a positive stock', fontsize=14)
plt.xlabel('Word', fontsize=14)
plt.ylabel('Chance', fontsize=14)
plt.xticks(rotation = 90)
plt.grid(True)
plt.show()

# %%
words = []
value = []
for i in top_up_words_long[:25]:
    words.append(i[0])
    value.append(i[1])

# %%
top_up_words_long.remove(('$', 72))
top_up_words_long.remove(('2020', 35))
top_up_words_long.remove(('2018', 27))
top_up_words_long.remove(('2019', 23))
top_up_words_long.remove(('Q4', 21))
top_up_words_long.remove(('fourth', 22))
top_up_words_long.remove(('2017', 20))
top_up_words_long.remove(('2021', 19))

# %%
top_up_words_long
# Out:
# [('year', 189),
#  ('growth', 146),
#  ('strong', 94),
#  ('$', 72),
#  ('quarter', 63),
#  ('customers', 56),
#  ('fiscal', 46),
#  ('record', 45),
#  ('billion', 44),
#  ('revenue', 44),
#  ('performance', 40),
#  ('business', 39),
#  ('2020', 35),
#  ('cash', 34),
#  ('results', 29),
#  ('2018', 27),
#  ('cloud', 24),
#  ('delivered', 23),
#  ('2019', 23),
#  ('fourth', 22),
#  ('Q4', 21),
#  ('continued', 21),
#  ('2017', 20),
#  ('sales', 19),
#  ('2021', 19),
#  ('term', 17),
#  ('Honeywell', 17),
#  ('long', 16),
#  ('flow', 16),
#  ('capital', 16),
#  ('world', 16),
#  ('new', 15),
#  ('earnings', 15),
#  ('Apple', 15),
#  ('company', 15),
#  ('Pfizer', 15),
#  ('customer', 14),
#  ('Affiliates', 14),
#  ('continue', 13),
#  ('said', 13),
#  ('Microsoft', 13),
#  ('product', 12),
#  ('shareholders', 12),
#  ('investments', 12),
#  ('operating', 12),
#  ('demand', 12),
#  ('great', 11),
#  ('AI', 11),
#  ('products', 11),
#  ('financial', 11),
#  ('global', 11),
#  ('pandemic', 11),
#  ('NVIDIA', 11),
#  ('challenging', 10),
#  ('percent', 10),
#  ('free', 10),
#  ('digital', 10),
#  ('services', 9),
#  ('significant', 9),
#  ('Alexa', 9),
#  ('share', 9),
#  ('AMG', 9),
#  ('pleased', 9),
#  ('employees', 9),
#  ('finish', 9),
#  ('drive', 9),
#  ('net', 9),
#  ('adjusted', 9),
#  ('McDonald', 9),
#  ('Oracle', 9),
#  ('volume', 9),
#  ('focus', 8),
#  ('clients', 8),
#  ('2022', 8),
#  ('cost', 8),
#  ('Amazon', 8),
#  ('solid', 8),
#  ('end', 8),
#  ('time', 8),
#  ('impact', 8),
#  ('COVID-19', 8),
#  ('healthcare', 8),
#  ('Starbucks', 8),
#  ('Visa', 8),
#  ('outstanding', 7),
#  ('achieved', 7),
#  ('help', 7),
#  ('Adobe', 7),
#  ('Prime', 7),
#  ('markets', 7),
#  ('Broadcom', 7),
#  ('dividend', 7),
#  ('Deere', 7),
#  ('NIKE', 7),
#  ('excellent', 7),
#  ('work', 7),
#  ('ServiceNow', 7),
#  ('service', 7),
#  ('organic', 6),
#  ('driving', 6),
#  ('momentum', 6),
#  ('value', 6),
#  ('constant', 6),
#  ('portfolio', 6),
#  ('strategic', 6),
#  ('environment', 6),
#  ('margin', 6),
#  ('focused', 6),
#  ('solutions', 6),
#  ('experience', 6),
#  ('hybrid', 6),
#  ('currency', 6),
#  ('deliver', 6),
#  ('consumers', 6),
#  ('finished', 6),
#  ('strategy', 6),
#  ('5', 6),
#  ('G', 6),
#  ('exceeded', 5),
#  ('businesses', 5),
#  ('delivering', 5),
#  ('including', 5),
#  ('investment', 5),
#  ('strength', 5),
#  ('grow', 5),
#  ('commercial', 5),
#  ('enterprise', 5),
#  ('software', 5),
#  ('infrastructure', 5),
#  ('team', 5),
#  ('resilience', 5),
#  ('system', 5),
#  ('health', 5),
#  ('ability', 5),
#  ('IQOS', 5),
#  ('operational', 5),
#  ('better', 5),
#  ('expected', 5),
#  ('good', 4),
#  ('EPS', 4),
#  ('proud', 4),
#  ('market', 4),
#  ('people', 4),
#  ('communities', 4),
#  ('U.S.', 4),
#  ('marked', 4),
#  ('generated', 4),
#  ('areas', 4),
#  ('ADI', 4),
#  ('high', 4),
#  ('concluded', 4),
#  ('September', 4),
#  ('goal', 4),
#  ('investing', 4),
#  ('Enterprise', 4),
#  ('completed', 4),
#  ('transformation', 4),
#  ('John', 4),
#  ('improved', 4),
#  ('GE', 4),
#  ('Anthem', 4),
#  ('greater', 4),
#  ('years', 4),
#  ('associates', 4),
#  ('spin', 4),
#  ('growing', 4),
#  ('platform', 4),
#  ('Velocity', 4),
#  ('Growth', 4),
#  ('Plan', 4),
#  ('intelligent', 4),
#  ('partnerships', 4),
#  ('chief', 4),
#  ('executive', 4),
#  ('officer', 4),
#  ('computing', 4),
#  ('information', 4),
#  ('Upjohn', 4),
#  ('best', 4),
#  ('recovery', 4),
#  ('men', 4),
#  ('pricing', 4),
#  ('productivity', 4),
#  ('network', 4),
#  ('Verizon', 4),
#  ('conditions', 3),
#  ('double', 3),
#  ('digit', 3),
#  ('demonstrate', 3),
#  ('unprecedented', 3),
#  ('structure', 3),
#  ('positive', 3),
#  ('delivery', 3),
#  ('day', 3),
#  ('invention', 3),
#  ('milestone', 3),
#  ('successfully', 3),
#  ('significantly', 3),
#  ('accelerated', 3),
#  ('annual', 3),
#  ('client', 3),
#  ('led', 3),
#  ('opportunity', 3),
#  ('travel', 3),
#  ('Symantec', 3),
#  ('Security', 3),
#  ('driven', 3),
#  ('highest', 3),
#  ('guidance', 3),
#  ('uncertainty', 3),
#  ('higher', 3),
#  ('result', 3),
#  ('launch', 3),
#  ('IngenioRx', 3),
#  ('industry', 3),
#  ('smoke', 3),
#  ('Intel', 3),
#  ('look', 3),
#  ('national', 3),
#  ('platforms', 3),
#  ('Applied', 3),
#  ('restaurants', 3),
#  ('grew', 3),
#  ('Cloud', 3),
#  ('database', 3),
#  ('Autonomous', 3),
#  ('Database', 3),
#  ('decisions', 3),
#  ('Liberty', 3),
#  ('expectations', 3),
#  ('women', 3),
#  ('highly', 2),
#  ('set', 2),
#  ('Despite', 2),
#  ('testament', 2),
#  ('line', 2),
#  ('Marketo', 2),
#  ('phenomenal', 2),
#  ('capped', 2),
#  ('FY20', 2),
#  ('Google', 2),
#  ('opportunities', 2),
#  ('revenues', 2),
#  ('far', 2),
#  ('developers', 2),
#  ('Echo', 2),
#  ('compared', 2),
#  ('number', 2),
#  ('working', 2),
#  ('doubled', 2),
#  ('hard', 2),
#  ('members', 2),
#  ('normal', 2),
#  ('yawn', 2),
#  ('AMD', 2),
#  ('EPYC', 2),
#  ('certain', 2),
#  ('B2B', 2),
#  ('analog', 2),
#  ('records', 2),
#  ('neutral', 2),
#  ('reducing', 2),
#  ('debt', 2),
#  ('connectivity', 2),
#  ('media', 2),
#  ('half', 2),
#  ('ago', 2),
#  ('safety', 2),
#  ('disruption', 2),
#  ('important', 2),
#  (' ', 2),
#  ('expect', 2),
#  ('segment', 2),
#  ('companies', 2),
#  ('Today', 2),
#  ('e', 2),
#  ('generation', 2),
#  ('profitable', 2),
#  ('returned', 2),
#  ('targets', 2),
#  ('invest', 2),
#  ('continuing', 2),
#  ('navigating', 2),
#  ('production', 2),
#  ('7', 2),
#  ('acquisition', 2),
#  ('reduced', 2),
#  ('Chevron', 2),
#  ('Noble', 2),
#  ('Energy', 2),
#  ('lower', 2),
#  ('carbon', 2),
#  ('future', 2),
#  ('quarterly', 2),
#  ('executing', 2),
#  ('dynamic', 2),
#  ('backlog', 2),
#  ('accomplishments', 2),
#  ('progress', 2),
#  ('crisis', 2),
#  ('equipment', 2),
#  ('operations', 2),
#  ('suppliers', 2),
#  ('supply', 2),
#  ('chain', 2),
#  ('issues', 2),
#  ('BioPharma', 2),
#  ('colleagues', 2),
#  ('Danaher', 2),
#  ('pivotal', 2),
#  ('capabilities', 2),
#  ('execution', 2),
#  ('transition', 2),
#  ('improving', 2),
#  ('close', 2),
#  ('reflecting', 2),
#  ('return', 2),
#  ('Home', 2),
#  ('Depot', 2),
#  ('Fiscal', 2),
#  ('increased', 2),
#  ('based', 2),
#  ('Lockheed', 2),
#  ('Martin', 2),
#  ('defense', 2),
#  ('emerging', 2),
#  ('ahead', 2),
#  ('Materials', 2),
#  ('closed', 2),
#  ('remain', 2),
#  ('making', 2),
#  ('consecutive', 2),
#  ('build', 2),
#  ('workers', 2),
#  ('way', 2),
#  ('incredible', 2),
#  ('drove', 2),
#  ('surpassing', 2),
#  ('25', 2),
#  ('FY19', 2),
#  ('gaming', 2),
#  ('RTX', 2),
#  ('GPUs', 2),
#  ('data', 2),
#  ('center', 2),
#  ('industries', 2),
#  ('forecast', 2),
#  ('non', 2),
#  ('GAAP', 2),
#  ('Mylan', 2),
#  ('science', 2),
#  ('believe', 2),
#  ('forward', 2),
#  ('FDA', 2),
#  ('authorized', 2),
#  ('PMI', 2),
#  ('headwinds', 2),
#  ('diluted', 2),
#  ('occupancy', 2),
#  ('midpoint', 2),
#  ('rent', 2),
#  ('expand', 2),
#  ('welcome', 2),
#  ('Prologis', 2),
#  ('create', 2),
#  ('Salesforce', 2),
#  ('13', 2),
#  ('1', 2),
#  ('million', 2),
#  ('enabling', 2),
#  ('workflow', 2),
#  ('agenda', 2),
#  ('underpinned', 2),
#  ('faster', 2),
#  ('partners', 2),
#  ('exceed', 2),
#  ('Reinvention', 2),
#  ('2023', 2),
#  ('leading', 2),
#  ('track', 2),
#  ('core', 2),
#  ('gains', 2),
#  ('Unified', 2),
#  ('providing', 2),
#  ('reliable', 2),
#  ('consistent', 2),
#  ('produce', 2),
#  ('dedicated', 2),
#  ('UnitedHealth', 2),
#  ('Group', 2),
#  ('Investor', 2),
#  ('Conference', 2),
#  ('improvements', 2),
#  ('thank', 2),
#  ('Europe', 2),
#  ('trends', 2),
#  ('consumer', 2),
#  ('payments', 2),
#  ('Walmart', 2),
#  ('performed', 1),
#  ('pipeline', 1),
#  ('productive', 1),
#  ('took', 1),
#  ('Abbott', 1),
#  ('range', 1),
#  ('tier', 1),
#  ('entering', 1),
#  ('ground', 1),
#  ('Accenture', 1),
#  ('exceptional', 1),
#  ('2', 1),
#  ('amidst', 1),
#  ('projections', 1),
#  ('optimistic', 1),
#  ('surprises', 1),
#  ('crazy', 1),
#  ('things', 1),
#  ('pioneered', 1),
#  ('reviews', 1),
#  ('key', 1),
#  ('inflection', 1),
#  ('point', 1),
#  ('shaped', 1),
#  ('second', 1),
#  ('straight', 1),
#  ('multi', 1),
#  ('journey', 1),
#  ('launched', 1),
#  ('ramped', 1),
#  ('expanding', 1),
#  ('backdrop', 1),
#  ('groundbreaking', 1),
#  ('profound', 1),
#  ('societal', 1),
#  ('Booking', 1),
#  ('Holdings', 1),
#  ('met', 1),
#  ('outlook', 1),
#  ('January', 1),
#  ('rebound', 1),
#  ('Caterpillar', 1),
#  ('profit', 1),
#  ('safely', 1),
#  ('proved', 1),
#  ('Financial', 1),
#  ('coming', 1),
#  ('Coca', 1),
#  ('Cola', 1),
#  ('Company', 1),
#  ('bottling', 1),
#  ('worked', 1),
#  ('tirelessly', 1),
#  ('demonstrated', 1),
#  ('flexibility', 1),
#  ('caused', 1),
#  ('able', 1),
#  ('effectively', 1),
#  ('manage', 1),
#  ('taking', 1),
#  ('bold', 1),
#  ('transaction', 1),
#  ('progressed', 1),
#  ('profitability', 1),
#  ('objectives', 1),
#  ('featuring', 1),
#  ('successful', 1),
#  ('uncertainties', 1),
#  ('benefits', 1),
#  ('past', 1),
#  ('effective', 1),
#  ('response', 1),
#  ('cycle', 1),
#  ('structural', 1),
#  ('savings', 1),
#  ('ongoing', 1),
#  ('commitment', 1),
#  ('enhance', 1),
#  ('interconnected', 1),
#  ('retail', 1),
#  ('provide', 1),
#  ('localized', 1),
#  ('innovative', 1),
#  ('foundation', 1),
#  ('adoption', 1),
#  ('truly', 1),
#  ('remarkable', 1),
#  ('corporation', 1),
#  ('breaking', 1),
#  ('semiconductor', 1),
#  ('remembered', 1),
#  ('inspiring', 1),
#  ('moments', 1),
#  ('history', 1),
#  ('challenges', 1),
#  ('System', 1),
#  ('came', 1),
#  ('unparalleled', 1),
#  ('dedication', 1),
#  ('community', 1),
#  ('use', 1),
#  ('Medtronic', 1),
#  ('acknowledge', 1),
#  ('heroism', 1),
#  ('Innovation', 1),
#  ('deep', 1),
#  ('months', 1),
#  ('clear', 1),
#  ('innovation', 1),
#  ('winning', 1),
#  ('international', 1),
#  ('bring', 1),
#  ('Consumer', 1),
#  ('Direct', 1),
#  ('Brand', 1),
#  ('continues', 1),
#  ('resonate', 1),
#  ('strongly', 1),
#  ('unmatched', 1),
#  ('brands', 1),
#  ('turbulent', 1),
#  ('Jensen', 1),
#  ('Huang', 1),
#  ('founder', 1),
#  ('CEO', 1),
#  ('Adoption', 1),
#  ('early', 1),
#  ('days', 1),
#  ('committed', 1),
#  ('capping', 1),
#  ('strongest', 1),
#  ('acquired', 1),
#  ('complementary', 1),
#  ('adding', 1),
#  ('class', 1),
#  ('efficient', 1),
#  ('propelled', 1),
#  ('10', 1),
#  ('delighted', 1),
#  ('raise', 1),
#  ('predicted', 1),
#  ('store', 1),
#  ('makes', 1),
#  ('incredibly', 1),
#  ('pivoted', 1),
#  ('adapt', 1),
#  ('beat', 1),
#  ('saw', 1),
#  ('accelerating', 1),
#  ('decade', 1),
#  ('achieving', 1),
#  ('8.1', 1),
#  ('spite', 1),
#  ('outbreaks', 1),
#  ('intensified', 1),
#  ('teams', 1),
#  ('showed', 1),
#  ('report', 1),
#  ('goals', 1),
#  ('executed', 1),
#  ('extremely', 1),
#  ('operated', 1),
#  ('speed', 1),
#  ('scale', 1),
#  ('Given', 1),
#  ('true', 1),
#  ('enter', 1),
#  ('serve', 1),
#  ('300,000', 1),
#  ('positively', 1),
#  ('impacting', 1),
#  ('society', 1),
#  ('restlessly', 1),
#  ('improve', 1),
#  ('outcomes', 1),
#  ('patient', 1),
#  ('prouder', 1),
#  ('325,000', 1),
#  ('role', 1),
#  ('advancing', 1),
#  ('performing', 1),
#  ('Transformation', 1),
#  ('enabled', 1),
#  ('UPS', 1),
#  ('embrace', 1),
#  ('surge', 1),
#  ('air', 1),
#  ('UPSers', 1),
#  ('loyalty', 1),
#  ('VVerizon', 1),
#  ('ended', 1),
#  ('began', 1),
#  ('robust', 1),
#  ('drivers', 1),
#  ('impacted', 1),
#  ('relatively', 1),
#  ('tumultuous', 1)]

# %%
plt.barh(words, value)
plt.title('Occurence of word for a positive stock', fontsize=14)
plt.xlabel('Occurence', fontsize=14)
plt.ylabel('Word', fontsize=14)
plt.xticks(rotation = 90)
plt.grid(True)
plt.show()

# %%
words = []
value = []
for i in top_down_words_long[:25]:
    words.append(i[0])
    value.append(i[1])

# %%
top_down_words_long.remove(('$', 31))
top_down_words_long.remove(('2021', 16))
top_down_words_long.remove(('Q4', 12))
top_down_words_long.remove(('2017', 12))
top_down_words_long.remove(('2019', 12))

# %%
top_down_words_long
# Out:
# [('growth', 100),
#  ('year', 96),
#  ('strong', 65),
#  ('quarter', 48),
#  ('$', 31),
#  ('performance', 30),
#  ('business', 30),
#  ('revenue', 24),
#  ('customers', 20),
#  ('fiscal', 17),
#  ('billion', 17),
#  ('2021', 16),
#  ('fourth', 16),
#  ('sales', 16),
#  ('cloud', 16),
#  ('businesses', 14),
#  ('Prime', 14),
#  ('Oracle', 14),
#  ('new', 13),
#  ('delivered', 13),
#  ('percent', 12),
#  ('financial', 12),
#  ('Q4', 12),
#  ('2017', 12),
#  ('2019', 12),
#  ('term', 10),
#  ('U.S.', 10),
#  ('NVIDIA', 10),
#  ('results', 9),
#  ('value', 9),
#  ('Amazon', 9),
#  ('Apple', 9),
#  ('like', 8),
#  ('excellent', 8),
#  ('cash', 8),
#  ('investments', 8),
#  ('outstanding', 7),
#  ('record', 7),
#  ('2018', 7),
#  ('strategy', 7),
#  ('company', 7),
#  ('continue', 7),
#  ('high', 7),
#  ('products', 7),
#  ('MySQL', 7),
#  ('great', 6),
#  ('product', 6),
#  ('million', 6),
#  ('delivering', 6),
#  ('commercial', 6),
#  ('2022', 6),
#  ('making', 6),
#  ('solid', 6),
#  ('Disney+', 6),
#  ('supply', 6),
#  ('AI', 6),
#  ('said', 6),
#  ('NIKE', 6),
#  ('EPS', 5),
#  ('people', 5),
#  ('drive', 5),
#  ('Affiliates', 5),
#  ('long', 5),
#  ('momentum', 5),
#  ('work', 5),
#  ('flow', 5),
#  ('grew', 5),
#  ('good', 5),
#  ('free', 5),
#  ('applications', 5),
#  ('margin', 5),
#  ('Database', 5),
#  ('tobacco', 5),
#  ('want', 5),
#  ('achieved', 4),
#  ('ongoing', 4),
#  ('Rings', 4),
#  ('members', 4),
#  ('price', 4),
#  ('AMG', 4),
#  ('Boeing', 4),
#  ('shareholders', 4),
#  ('returning', 4),
#  ('end', 4),
#  ('increase', 4),
#  ('construction', 4),
#  ('equipment', 4),
#  ('Disney', 4),
#  ('GE', 4),
#  ('strengthen', 4),
#  ('portfolio', 4),
#  ('Honeywell', 4),
#  ('expectations', 4),
#  ('operating', 4),
#  ('Fusion', 4),
#  ('earnings', 4),
#  ('IQOS', 4),
#  ('eCommerce', 4),
#  ('associates', 4),
#  ('clients', 3),
#  ('progress', 3),
#  ('Adobe', 3),
#  ('investment', 3),
#  ('areas', 3),
#  ('iPhone', 3),
#  ('September', 3),
#  ('positive', 3),
#  ('HBO', 3),
#  ('focused', 3),
#  ('737', 3),
#  ('MAX', 3),
#  ('brands', 3),
#  ('line', 3),
#  ('travel', 3),
#  ('significantly', 3),
#  ('Deere', 3),
#  ('IBM', 3),
#  ('store', 3),
#  ('Intel', 3),
#  ('finish', 3),
#  ('completed', 3),
#  ('demand', 3),
#  ('chain', 3),
#  ('digital', 3),
#  ('platform', 3),
#  ('ERP', 3),
#  ('smoke', 3),
#  ('reduced', 3),
#  ('risk', 3),
#  ('adjusted', 3),
#  ('global', 3),
#  ('Starbucks', 3),
#  ('Verizon', 3),
#  ('started', 3),
#  ('stores', 3),
#  ('Walmart', 3),
#  ('helped', 2),
#  ('Cloud', 2),
#  ('AMD', 2),
#  ('data', 2),
#  ('center', 2),
#  ('range', 2),
#  ('strongest', 2),
#  ('impact', 2),
#  ('broadband', 2),
#  ('postpaid', 2),
#  ('phone', 2),
#  ('net', 2),
#  ('adds', 2),
#  ('ended', 2),
#  ('services', 2),
#  ('team', 2),
#  ('focus', 2),
#  ('driving', 2),
#  ('programs', 2),
#  ('production', 2),
#  ('returned', 2),
#  ('recovery', 2),
#  ('customer', 2),
#  ('operational', 2),
#  ('excellence', 2),
#  ('early', 2),
#  ('profitable', 2),
#  ('implementing', 2),
#  ('dividend', 2),
#  ('emission', 2),
#  ('gas', 2),
#  ('operations', 2),
#  ('order', 2),
#  ('transformation', 2),
#  ('markets', 2),
#  ('farm', 2),
#  ('reflect', 2),
#  ('streaming', 2),
#  ('DTC', 2),
#  ('best', 2),
#  ('direct', 2),
#  ('subscriptions', 2),
#  ('total', 2),
#  ('execution', 2),
#  ('low', 2),
#  ('guidance', 2),
#  ('committed', 2),
#  ('strategic', 2),
#  ('position', 2),
#  ('blockchain', 2),
#  ('acquisition', 2),
#  ('share', 2),
#  ('expanded', 2),
#  ('exceeded', 2),
#  ('capping', 2),
#  ('quarterly', 2),
#  ('exceptional', 2),
#  ('semiconductor', 2),
#  ('orders', 2),
#  ('Semiconductor', 2),
#  ('Systems', 2),
#  ('Demand', 2),
#  ('continued', 2),
#  ('ahead', 2),
#  ('reported', 2),
#  ('chief', 2),
#  ('executive', 2),
#  ('officer', 2),
#  ('Microsoft', 2),
#  ('consumer', 2),
#  ('GPU', 2),
#  ('computing', 2),
#  ('non', 2),
#  ('GAAP', 2),
#  ('capital', 2),
#  ('allocation', 2),
#  ('pipeline', 2),
#  ('structure', 2),
#  ('currency', 2),
#  ('robust', 2),
#  ('inventory', 2),
#  ('heated', 2),
#  ('volume', 2),
#  ('combustible', 2),
#  ('diluted', 2),
#  ('digit', 2),
#  ('pandemic', 2),
#  ('proven', 2),
#  ('FY23', 2),
#  ('comparable', 2),
#  ('partners', 2),
#  ('exceed', 2),
#  ('Reinvention', 2),
#  ('2023', 2),
#  ('organic', 2),
#  ('meet', 2),
#  ('network', 2),
#  ('significant', 2),
#  ('thank', 2),
#  ('deliver', 2),
#  ('serve', 2),
#  ('McMillon', 2),
#  ('capabilities', 2),
#  ('Abbott', 1),
#  ('40', 1),
#  ('exceeding', 1),
#  ('proud', 1),
#  ('resulted', 1),
#  ('annual', 1),
#  ('profitability', 1),
#  ('ADI', 1),
#  ('profits', 1),
#  ('tax', 1),
#  ('reform', 1),
#  ('regulatory', 1),
#  ('rationalization', 1),
#  ('substantial', 1),
#  ('economy', 1),
#  ('AT&T.', 1),
#  ('promised', 1),
#  ('begin', 1),
#  ('wireless', 1),
#  ('Max', 1),
#  ('recognize', 1),
#  ('lot', 1),
#  ('service', 1),
#  ('safely', 1),
#  ('rebuilding', 1),
#  ('Booking', 1),
#  ('Holdings', 1),
#  ('finished', 1),
#  ('Despite', 1),
#  ('negative', 1),
#  ('Omicron', 1),
#  ('wave', 1),
#  ('challenging', 1),
#  ('years', 1),
#  ('Earnings', 1),
#  ('objective', 1),
#  ('Cash', 1),
#  ('commitments', 1),
#  ('growing', 1),
#  ('sustainable', 1),
#  ('way', 1),
#  ('strength', 1),
#  ('spent', 1),
#  ('productive', 1),
#  ('Walt', 1),
#  ('Company', 1),
#  ('excluding', 1),
#  ('insurance', 1),
#  ('related', 1),
#  ('marked', 1),
#  ('exploration', 1),
#  ('success', 1),
#  ('acquisitions', 1),
#  ('period', 1),
#  ('commodity', 1),
#  ('prices', 1),
#  ('adding', 1),
#  ('add', 1),
#  ('attractive', 1),
#  ('assets', 1),
#  ('positioned', 1),
#  ('performed', 1),
#  ('short', 1),
#  ('length', 1),
#  ('downstream', 1),
#  ('chemicals', 1),
#  ('impacted', 1),
#  ('imperatives', 1),
#  ('double', 1),
#  ('note', 1),
#  ('gained', 1),
#  ('addressable', 1),
#  ('market', 1),
#  ('demands', 1),
#  ('process', 1),
#  ('fifth', 1),
#  ('consecutive', 1),
#  ('represented', 1),
#  ('corporation', 1),
#  ('achieving', 1),
#  ('Applied', 1),
#  ('Materials', 1),
#  ('healthy', 1),
#  ('uptick', 1),
#  ('semiconductors', 1),
#  ('turned', 1),
#  ('stay', 1),
#  ('connected', 1),
#  ('use', 1),
#  ('Global', 1),
#  ('COVID-19', 1),
#  ('controls', 1),
#  ('China', 1),
#  ('created', 1),
#  ('acute', 1),
#  ('impacts', 1),
#  ('seeing', 1),
#  ('platforms', 1),
#  ('Jensen', 1),
#  ('WOur', 1),
#  ('testament', 1),
#  ('quality', 1),
#  ('1', 1),
#  ('square', 1),
#  ('foot', 1),
#  ('shows', 1),
#  ('signs', 1),
#  ('slowing', 1),
#  ('beat', 1),
#  ('saw', 1),
#  ('accelerating', 1),
#  ('coffee', 1),
#  ('pre', 1),
#  ('announced', 1),
#  ('8', 1),
#  ('despite', 1),
#  ('challenges', 1),
#  ('execute', 1),
#  ('powered', 1),
#  ('PPI', 1),
#  ('Business', 1),
#  ('Union', 1),
#  ('target', 1),
#  ('UPSers', 1),
#  ('efforts', 1),
#  ('holiday', 1),
#  ('season', 1),
#  ('industry', 1),
#  ('leading', 1),
#  ('Comp', 1),
#  ('globally', 1),
#  ('26', 1),
#  ('leveraged', 1),
#  ('expenses', 1),
#  ('pleased', 1),
#  ('comp', 1),
#  ('result', 1),
#  ('outside', 1),
#  ('membership', 1),
#  ('trends', 1),
#  ('Sam', 1),
#  ('openness', 1),
#  ('segments', 1),
#  ('aggressive', 1),
#  ('plans', 1),
#  ('executing', 1)]

# %%
plt.barh(words, value)
plt.title('Occurence of word for a negative stock', fontsize=14)
plt.xlabel('Occurence', fontsize=14)
plt.ylabel('Word', fontsize=14)
plt.xticks(rotation = 90)
plt.grid(True)
plt.show()

# %%
result
# Out:
#           Date   Adj Close     Volume  \
# 36  2018-01-01   56.711449  156001900
# 48  2019-01-01   67.803299  157850300
# 60  2020-01-01   82.301605  119657000
# 72  2021-01-01  118.568031  108930500
# 84  2022-01-01  124.170898  155539600
# ..         ...         ...        ...
# 37  2018-02-01   81.499840  307532700
# 49  2019-02-01   91.758194  166799500
# 61  2020-02-01  101.834824  132414100
# 73  2021-02-01  124.918640  184999800
# 85  2022-02-01  132.023560  162588100
#
#                                         press release  Compound  Negative  \
# 36  2017 was a great year for us — we performed we...    0.8882     0.000
# 48  2018 was another outstanding year for Abbott. ...    0.9217     0.000
# 60  Our focus on organic growth is driving top-tie...    0.8932     0.000
# 72  Despite challenging conditions, we achieved do...    0.8103     0.031
# 84  2021 was an outstanding year for Abbott. We ac...    0.8360     0.000
# ..                                                ...       ...       ...
# 37  We have good momentum in the business with sol...    0.9758     0.000
# 49  We had a good year, and I want to thank our as...    0.9913     0.000
# 61  We thank our associates for another good year....    0.9945     0.029
# 73  We completed a strong year and a strong Q4 tha...    0.9887     0.009
# 85  We had another strong quarter to finish off a ...    0.8591     0.029
#
#     Neutral  Positive  polarity  subjectivity  ...  upper_case_word_count  \
# 36    0.723     0.277  0.505273      0.704909  ...                      0
# 48    0.725     0.275  0.362500      0.731250  ...                      0
# 60    0.592     0.408  0.671667      0.756667  ...                      0
# 72    0.757     0.212  0.384091      0.638636  ...                      2
# 84    0.806     0.194  0.307273      0.579242  ...                      2
# ..      ...       ...       ...           ...  ...                    ...
# 37    0.676     0.324  0.325000      0.377778  ...                      2
# 49    0.635     0.365  0.411970      0.587121  ...                      1
# 61    0.751     0.220  0.228437      0.476852  ...                      5
# 73    0.810     0.182  0.285088      0.561404  ...                      2
# 85    0.772     0.199  0.388889      0.755556  ...                      0
#
#     stopword_count  noun_count  verb_count  adj_count  adv_count  pron_count  \
# 36              12           8           6          6          5           4
# 48              18          14           6          6          2           5
# 60               6           5           6          4          1           2
# 72              15          12           6          5          0           3
# 84              14          12           6          5          1           3
# ..             ...         ...         ...        ...        ...         ...
# 37              28          22          14          6          0           8
# 49              43          22          22         10          6          14
# 61             104          86          35         28          9          20
# 73              74          58          40         22         17          19
# 85              23          12          13          5          2           7
#
#                                             top_words  Price change sign long  \
# 36  [(2017, 1), (great, 1), (year, 1), (performed,...                       1
# 48  [(year, 2), (2018, 1), (outstanding, 1), (Abbo...                       1
# 60  [(growth, 2), (focus, 1), (organic, 1), (drivi...                       1
# 72  [(EPS, 2), (growth, 2), (Despite, 1), (challen...                       1
# 84  [(year, 2), (EPS, 2), (2021, 1), (outstanding,...                      -1
# ..                                                ...                     ...
# 37  [(business, 2), (making, 2), (work, 2), (custo...                      -1
# 49  [(want, 2), (work, 2), (customers, 2), (delive...                      -1
# 61  [(strong, 5), (quarter, 5), (sales, 5), (U.S.,...                      -1
# 73  [(strong, 4), (associates, 3), (customers, 3),...                      -1
# 85  [(strong, 2), (business, 2), (quarter, 1), (fi...                      -1
#
#     word_calculation
# 36          1.450746
# 48          0.627955
# 60          1.113614
# 72          0.222914
# 84          1.858078
# ..               ...
# 37          0.256427
# 49          0.462493
# 61          0.000344
# 73          0.420966
# 85          0.108451
#
# [248 rows x 26 columns]

# %% [markdown]
# # top words for short sign

# %%
top_up_words_short = {}
for i in result[result['Price change sign short'] == 1]['top_words']:
    for j in i:
        if j[0] in top_up_words_short:
            top_up_words_short[j[0]] += j[1]
        else:
            top_up_words_short[j[0]] = j[1]
            
top_up_words_short = sorted(top_up_words_short.items(), key=lambda x:x[1], reverse=True)
print(top_up_words_short)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Price change sign short'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[64], line 2
#       1 top_up_words_short = {}
# ----> 2 for i in result[result['Price change sign short'] == 1]['top_words']:
#       3     for j in i:
#       4         if j[0] in top_up_words_short:
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Price change sign short'

# %%
top_down_words_short = {}
for i in result[result['Price change sign short'] == -1]['top_words']:
    for j in i:
        if j[0] in top_down_words_short:
            top_down_words_short[j[0]] += j[1]
        else:
            top_down_words_short[j[0]] = j[1]
            
top_down_words_short = sorted(top_down_words_short.items(), key=lambda x:x[1], reverse=True)

#normalize 116 postive and 27 negative = 168/80 = 2.1
top_down_words_short_new = []
for key, value in top_down_words_short:
    value = value * 2.1
    top_down_words_short_new.append(tuple([key, int(value)])) 

print(top_down_words_short_new)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Price change sign short'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[65], line 2
#       1 top_down_words_short = {}
# ----> 2 for i in result[result['Price change sign short'] == -1]['top_words']:
#       3     for j in i:
#       4         if j[0] in top_down_words_short:
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Price change sign short'

# %%
top_down_words_short_dict = {}

for i in top_down_words_short_new:
    if i[0] in top_down_words_short_dict:
        top_down_words_short_dict[i[0]] += i[1]
    else:
        top_down_words_short_dict[i[0]] = i[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 3
#       1 top_down_words_short_dict = {}
# ----> 3 for i in top_down_words_short_new:
#       4     if i[0] in top_down_words_short_dict:
#       5         top_down_words_short_dict[i[0]] += i[1]
#
# NameError: name 'top_down_words_short_new' is not defined

# %%
# difference between list where the number followed by the word is the times it occurs more in POSTIVE 1
difference_list_short = []
for i in top_up_words_short[:25]:
    if i[0] in top_down_words_short_dict:
        difference = i[1] / top_down_words_short_dict[i[0]]
        difference_list_short.append(tuple([i[0], difference]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 3
#       1 # difference between list where the number followed by the word is the times it occurs more in POSTIVE 1
#       2 difference_list_short = []
# ----> 3 for i in top_up_words_short[:25]:
#       4     if i[0] in top_down_words_short_dict:
#       5         difference = i[1] / top_down_words_short_dict[i[0]]
#
# TypeError: unhashable type: 'slice'

# %%
difference_list_short
# Out:
# []

# %%
result
# Out:
#           Date   Adj Close     Volume  \
# 36  2018-01-01   56.711449  156001900
# 48  2019-01-01   67.803299  157850300
# 60  2020-01-01   82.301605  119657000
# 72  2021-01-01  118.568031  108930500
# 84  2022-01-01  124.170898  155539600
# ..         ...         ...        ...
# 37  2018-02-01   81.499840  307532700
# 49  2019-02-01   91.758194  166799500
# 61  2020-02-01  101.834824  132414100
# 73  2021-02-01  124.918640  184999800
# 85  2022-02-01  132.023560  162588100
#
#                                         press release  Compound  Negative  \
# 36  2017 was a great year for us — we performed we...    0.8882     0.000
# 48  2018 was another outstanding year for Abbott. ...    0.9217     0.000
# 60  Our focus on organic growth is driving top-tie...    0.8932     0.000
# 72  Despite challenging conditions, we achieved do...    0.8103     0.031
# 84  2021 was an outstanding year for Abbott. We ac...    0.8360     0.000
# ..                                                ...       ...       ...
# 37  We have good momentum in the business with sol...    0.9758     0.000
# 49  We had a good year, and I want to thank our as...    0.9913     0.000
# 61  We thank our associates for another good year....    0.9945     0.029
# 73  We completed a strong year and a strong Q4 tha...    0.9887     0.009
# 85  We had another strong quarter to finish off a ...    0.8591     0.029
#
#     Neutral  Positive  polarity  subjectivity  ...  upper_case_word_count  \
# 36    0.723     0.277  0.505273      0.704909  ...                      0
# 48    0.725     0.275  0.362500      0.731250  ...                      0
# 60    0.592     0.408  0.671667      0.756667  ...                      0
# 72    0.757     0.212  0.384091      0.638636  ...                      2
# 84    0.806     0.194  0.307273      0.579242  ...                      2
# ..      ...       ...       ...           ...  ...                    ...
# 37    0.676     0.324  0.325000      0.377778  ...                      2
# 49    0.635     0.365  0.411970      0.587121  ...                      1
# 61    0.751     0.220  0.228437      0.476852  ...                      5
# 73    0.810     0.182  0.285088      0.561404  ...                      2
# 85    0.772     0.199  0.388889      0.755556  ...                      0
#
#     stopword_count  noun_count  verb_count  adj_count  adv_count  pron_count  \
# 36              12           8           6          6          5           4
# 48              18          14           6          6          2           5
# 60               6           5           6          4          1           2
# 72              15          12           6          5          0           3
# 84              14          12           6          5          1           3
# ..             ...         ...         ...        ...        ...         ...
# 37              28          22          14          6          0           8
# 49              43          22          22         10          6          14
# 61             104          86          35         28          9          20
# 73              74          58          40         22         17          19
# 85              23          12          13          5          2           7
#
#                                             top_words  Price change sign long  \
# 36  [(2017, 1), (great, 1), (year, 1), (performed,...                       1
# 48  [(year, 2), (2018, 1), (outstanding, 1), (Abbo...                       1
# 60  [(growth, 2), (focus, 1), (organic, 1), (drivi...                       1
# 72  [(EPS, 2), (growth, 2), (Despite, 1), (challen...                       1
# 84  [(year, 2), (EPS, 2), (2021, 1), (outstanding,...                      -1
# ..                                                ...                     ...
# 37  [(business, 2), (making, 2), (work, 2), (custo...                      -1
# 49  [(want, 2), (work, 2), (customers, 2), (delive...                      -1
# 61  [(strong, 5), (quarter, 5), (sales, 5), (U.S.,...                      -1
# 73  [(strong, 4), (associates, 3), (customers, 3),...                      -1
# 85  [(strong, 2), (business, 2), (quarter, 1), (fi...                      -1
#
#     word_calculation
# 36          1.450746
# 48          0.627955
# 60          1.113614
# 72          0.222914
# 84          1.858078
# ..               ...
# 37          0.256427
# 49          0.462493
# 61          0.000344
# 73          0.420966
# 85          0.108451
#
# [248 rows x 26 columns]

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
import seaborn as sns 

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
X = np.array(result[['polarity', 'punctuation_count', 'noun_count', 'upper_case_word_count', 'word_count', 'word_calculation', 
                    'subjectivity']])
y = np.array(result['Price change sign long'])
# train-test splitting
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,  shuffle=True)

print(f"Train data shapes X:{X_train.shape} , y:{y_train.shape}")
print(f"Test data shapes X:{X_test.shape} , y:{y_test.shape}")
# Out:
# Train data shapes X:(173, 7) , y:(173,)
# Test data shapes X:(75, 7) , y:(75,)

# %%
result.columns
# Out:
# Index(['Date', 'Adj Close', 'Volume', 'press release', 'Compound', 'Negative',
#        'Neutral', 'Positive', 'polarity', 'subjectivity', 'text length',
#        'char_count', 'word_count', 'word_density', 'punctuation_count',
#        'title_word_count', 'upper_case_word_count', 'stopword_count',
#        'noun_count', 'verb_count', 'adj_count', 'adv_count', 'pron_count',
#        'top_words', 'Price change sign long', 'word_calculation'],
#       dtype='object')

# %%
from sklearn.metrics import make_scorer,f1_score, accuracy_score,precision_score, recall_score, f1_score
scoring = {'accuracy' : make_scorer(accuracy_score, greater_is_better=True), 
           'f1_macro' : make_scorer(f1_score, average='macro', greater_is_better=True),
           'precision' : make_scorer(precision_score, zero_division=0),
           'recall' : make_scorer(recall_score, average='macro') }

# %%
for solver in [ 'newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'] :
    print("-----------"*10)
    print("Training Logistic Regression with solver ",solver)
    logisticRegr = LogisticRegression(penalty='l2', solver=solver)
    logisticRegr.fit(X_train, y_train)

    # predict model
    # Predict for One Observation
    logisticRegr.predict(X_test[0].reshape(1,-1))

    cv_scores = cross_validate(logisticRegr, X_train, y_train, cv=5, scoring=scoring)
    accs = cv_scores['test_accuracy'].mean()
    print("Mean accs : ",accs)
    f1_macros = cv_scores['test_f1_macro'].mean()
    print("Mean f1_macro", f1_macros)
    prec = cv_scores['test_precision'].mean()
    print("Mean precision", prec)
    recall = cv_scores['test_recall'].mean()
    print("Mean recall", recall)
    
    predictions = logisticRegr.predict(X_test)
    cm = confusion_matrix(y_test, predictions, labels=logisticRegr.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                             display_labels=logisticRegr.classes_)
    disp.plot()
    plt.show()
# Out:
# --------------------------------------------------------------------------------------------------------------
# Training Logistic Regression with solver  newton-cg
# Mean accs :  0.630420168067227
# Mean f1_macro 0.400477063486001
# Mean precision 0.6533333333333333
# Mean recall 0.4778985507246377
# --------------------------------------------------------------------------------------------------------------
# Training Logistic Regression with solver  lbfgs
# Mean accs :  0.6363025210084035
# Mean f1_macro 0.4026073893005373
# Mean precision 0.6552941176470588
# Mean recall 0.4822463768115942
# --------------------------------------------------------------------------------------------------------------
# Training Logistic Regression with solver  liblinear
# Mean accs :  0.6363025210084035
# Mean f1_macro 0.4021848387547117
# Mean precision 0.6545523036800928
# Mean recall 0.48224637681159416
# --------------------------------------------------------------------------------------------------------------
# Training Logistic Regression with solver  sag
# Mean accs :  0.6305882352941177
# Mean f1_macro 0.39509981851179676
# Mean precision 0.6528571428571428
# Mean recall 0.4778985507246377
# --------------------------------------------------------------------------------------------------------------
# Training Logistic Regression with solver  saga
# Mean accs :  0.6591596638655461
# Mean f1_macro 0.39721718088324265
# Mean precision 0.662857142857143
# Mean recall 0.49565217391304345

# %%
logisticRegr = LogisticRegression(penalty='l2', solver='liblinear')
logisticRegr.fit(X_train, y_train)
# Use score method to get accuracy of model
score = logisticRegr.score(X_test, y_test)
print("Accuracy on test set : ",score)
# Out:
# Accuracy on test set :  0.72

# %%
for k in [2, 5 ,10]:
    print("---------"*10)
    print("Training with k = ",k)
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(X_train, y_train)

    # Cross 5 fold validation
    cv_scores = cross_validate(knn, X_train, y_train, cv=5, scoring=scoring)
    accs = cv_scores['test_accuracy'].mean()
    print("Mean accs : ",accs)
    f1_macros = cv_scores['test_f1_macro'].mean()
    print("Mean f1_macro", f1_macros)
    prec = cv_scores['test_precision'].mean()
    print("Mean precision", prec)
    recall = cv_scores['test_recall'].mean()
    print("Mean recall", recall)

    # cONFUSION matrix
    predictions = knn.predict(X_test)
    cm = confusion_matrix(y_test, predictions, labels=knn.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                             display_labels=knn.classes_)
    disp.plot()
    plt.show()
# Out:
# ------------------------------------------------------------------------------------------
# Training with k =  2
# Mean accs :  0.37025210084033616
# Mean f1_macro 0.3654271038558964
# Mean precision 0.5513903743315508
# Mean recall 0.3917325428194993
# ------------------------------------------------------------------------------------------
# Training with k =  5
# Mean accs :  0.6060504201680672
# Mean f1_macro 0.4665221436331276
# Mean precision 0.6601347661084069
# Mean recall 0.49617918313570486
# ------------------------------------------------------------------------------------------
# Training with k =  10
# Mean accs :  0.5717647058823528
# Mean f1_macro 0.4417767270486649
# Mean precision 0.6447203801945182
# Mean recall 0.46534914361001317

# %%
knn = KNeighborsClassifier(n_neighbors = 9)
knn.fit(X_train, y_train)
# Use score method to get accuracy of model
score = knn.score(X_test, y_test)
print("Accuracy on test set : ",score)
# Out:
# Accuracy on test set :  0.5866666666666667

# %%
for kernel in {'linear', 'poly', 'rbf', 'sigmoid'}:
    print("---------"*10)
    print("Training SVM with kernel ", kernel)
    clf = svm.SVC(kernel=kernel)
    clf.fit(X_train, y_train)
    
     # Cross 5 fold validation
    cv_scores = cross_validate(clf, X_train, y_train, cv=5, scoring=scoring)
    accs = cv_scores['test_accuracy'].mean()
    print("Mean accs : ",accs)
    f1_macros = cv_scores['test_f1_macro'].mean()
    print("Mean f1_macro", f1_macros)
    prec = cv_scores['test_precision'].mean()
    print("Mean precision", prec)
    recall = cv_scores['test_recall'].mean()
    print("Mean recall", recall)

    # cONFUSION matrix
    predictions = clf.predict(X_test)
    cm = confusion_matrix(y_test, predictions, labels=clf.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                             display_labels=clf.classes_)
    disp.plot()
    plt.show()
# Out:
# ------------------------------------------------------------------------------------------
# Training SVM with kernel  linear
# Mean accs :  0.664873949579832
# Mean f1_macro 0.3993345432546884
# Mean precision 0.664873949579832
# Mean recall 0.5
# ------------------------------------------------------------------------------------------
# Training SVM with kernel  poly
# Mean accs :  0.6534453781512605
# Mean f1_macro 0.39502419842710224
# Mean precision 0.6607181054239879
# Mean recall 0.4913043478260869
# ------------------------------------------------------------------------------------------
# Training SVM with kernel  rbf
# Mean accs :  0.664873949579832
# Mean f1_macro 0.3993345432546884
# Mean precision 0.664873949579832
# Mean recall 0.5
# ------------------------------------------------------------------------------------------
# Training SVM with kernel  sigmoid
# Mean accs :  0.5494117647058824
# Mean f1_macro 0.4377464223643823
# Mean precision 0.6389465706707085
# Mean recall 0.45592885375494063

# %%
clf = svm.SVC(kernel='rbf')
clf.fit(X_train, y_train)
clf.predict(X_test)
print(f'Kernel: rbf, score: {clf.score(X_test, y_test)}')
# Out:
# Kernel: rbf, score: 0.7066666666666667

# %%
for criterion in ['entropy', 'gini'] :
   # print("---------"*10)
   # print("Training Random Forest with criterion ", criterion)
    
    
    for leafs in [2, 3, 5, 10] :
        print("---------"*10)
        print("Training Random Forest with criterion ", criterion, ",  nodes =",leafs)

        rf = DecisionTreeClassifier(criterion=criterion, max_leaf_nodes=leafs)
        rf.fit(X_train, y_train)

         # Cross 5 fold validation
        cv_scores = cross_validate(rf, X, y, cv=5, scoring=scoring)
        accs = cv_scores['test_accuracy'].mean()
        print("Mean accs : ",accs)
        f1_macros = cv_scores['test_f1_macro'].mean()
        print("Mean f1_macro", f1_macros)
        prec = cv_scores['test_precision'].mean()
        print("Mean precision", prec)
        recall = cv_scores['test_recall'].mean()
        print("Mean recall", recall)

        # cONFUSION matrix
        predictions = rf.predict(X_test)
        cm = confusion_matrix(y_test, predictions, labels=rf.classes_)
        disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                                 display_labels=rf.classes_)
        disp.plot()
        plt.show()
# Out:
# ------------------------------------------------------------------------------------------
# Training Random Forest with criterion  entropy ,  nodes = 2
# Mean accs :  0.6732244897959184
# Mean f1_macro 0.4330732148800185
# Mean precision 0.6805343030829354
# Mean recall 0.5068070409982175
# ------------------------------------------------------------------------------------------
# Training Random Forest with criterion  entropy ,  nodes = 3
# Mean accs :  0.6732244897959184
# Mean f1_macro 0.4330732148800185
# Mean precision 0.6805343030829354
# Mean recall 0.5068070409982175
# ------------------------------------------------------------------------------------------
# Training Random Forest with criterion  entropy ,  nodes = 5
# Mean accs :  0.6242448979591837
# Mean f1_macro 0.4389348825259816
# Mean precision 0.6667033096926713
# Mean recall 0.48332219251336905
# ------------------------------------------------------------------------------------------
# Training Random Forest with criterion  entropy ,  nodes = 10
# Mean accs :  0.6124081632653061
# Mean f1_macro 0.46213410832215895
# Mean precision 0.6689895741342632
# Mean recall 0.4877339572192514
# ------------------------------------------------------------------------------------------
# Training Random Forest with criterion  gini ,  nodes = 2
# Mean accs :  0.6732244897959184
# Mean f1_macro 0.4330732148800185
# Mean precision 0.6805343030829354
# Mean recall 0.5068070409982175
# ------------------------------------------------------------------------------------------
# Training Random Forest with criterion  gini ,  nodes = 3
# Mean accs :  0.6853877551020409
# Mean f1_macro 0.47577189534185677
# Mean precision 0.6935907029478459
# Mean recall 0.532174688057041
# ------------------------------------------------------------------------------------------
# Training Random Forest with criterion  gini ,  nodes = 5
# Mean accs :  0.640408163265306
# Mean f1_macro 0.4867331873204678
# Mean precision 0.68340130468014
# Mean recall 0.5149398395721925
# ------------------------------------------------------------------------------------------
# Training Random Forest with criterion  gini ,  nodes = 10
# Mean accs :  0.632326530612245
# Mean f1_macro 0.5419754873333286
# Mean precision 0.7092716546567759
# Mean recall 0.5517156862745097

# %%
rf = DecisionTreeClassifier(criterion='entropy', max_leaf_nodes=5)
rf.fit(X_train, y_train)
score = rf.score(X_test, y_test)
print("Accuracy on Test set for 'optimal' random forest is :", score)
# cONFUSION matrix
predictions = rf.predict(X_test)
cm = confusion_matrix(y_test, predictions, labels=rf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                         display_labels=rf.classes_)
disp.plot()
plt.show()
# Out:
# Accuracy on Test set for 'optimal' random forest is : 0.72

# %%
rf.feature_importances_
# Out:
# array([0.22501085, 0.        , 0.        , 0.        , 0.        ,
#        0.57957097, 0.19541818])

# %%
result.to_csv('result dataset.csv')

# %%
METAFEATURES = ['polarity', 'punctuation_count', 'noun_count', 'upper_case_word_count', 'word_count', 'word_calculation', 
                    'subjectivity']
DISASTER_TWEETS = result['Price change sign long'] == 1

fig, axes = plt.subplots(ncols=2, nrows=len(METAFEATURES), figsize=(20, 50), dpi=100)

for i, feature in enumerate(METAFEATURES):
    sns.distplot(result.loc[~DISASTER_TWEETS][feature], label='Negative stock', ax=axes[i][0], color='green')
    sns.distplot(result.loc[DISASTER_TWEETS][feature], label='Postive stock', ax=axes[i][0], color='red')

    sns.distplot(result[feature], label='Training', ax=axes[i][1])
    sns.distplot(result[feature], label='Test', ax=axes[i][1])
    
    for j in range(2):
        axes[i][j].set_xlabel('')
        axes[i][j].tick_params(axis='x', labelsize=12)
        axes[i][j].tick_params(axis='y', labelsize=12)
        axes[i][j].legend()
    
    axes[i][0].set_title(f'{feature} Target Distribution in Training Set', fontsize=13)
    axes[i][1].set_title(f'{feature} Training & Test Set Distribution', fontsize=13)

plt.show()

# %%
METAFEATURES = ['polarity', 'punctuation_count', 'noun_count', 'upper_case_word_count', 'word_count', 'word_calculation', 
                    'subjectivity']
DISASTER_TWEETS = result['Price change sign long'] == 1

fig, axes = plt.subplots(ncols=1, nrows=len(METAFEATURES), figsize=(20, 50), dpi=100)

for i, feature in enumerate(METAFEATURES):
    sns.distplot(result.loc[~DISASTER_TWEETS][feature], label='Negative stock', ax=axes[i], color='green')
    sns.distplot(result.loc[DISASTER_TWEETS][feature], label='Postive stock', ax=axes[i], color='red')

    sns.distplot(result[feature], label='Training', ax=axes[i])
    sns.distplot(result[feature], label='Test', ax=axes[i])
    
    for j in range(2):
        axes[j].set_xlabel('')
        axes[j].tick_params(axis='x', labelsize=12)
        axes[j].tick_params(axis='y', labelsize=12)
        axes[j].legend()
    
    axes[j].set_title(f'{feature} Target Distribution in Training Set', fontsize=13)
    axes[j].set_title(f'{feature} Training & Test Set Distribution', fontsize=13)

plt.show()

# %%
result.head()
# Out:
#           Date   Adj Close     Volume  \
# 36  2018-01-01   56.711449  156001900
# 48  2019-01-01   67.803299  157850300
# 60  2020-01-01   82.301605  119657000
# 72  2021-01-01  118.568031  108930500
# 84  2022-01-01  124.170898  155539600
#
#                                         press release  Compound  Negative  \
# 36  2017 was a great year for us — we performed we...    0.8882     0.000
# 48  2018 was another outstanding year for Abbott. ...    0.9217     0.000
# 60  Our focus on organic growth is driving top-tie...    0.8932     0.000
# 72  Despite challenging conditions, we achieved do...    0.8103     0.031
# 84  2021 was an outstanding year for Abbott. We ac...    0.8360     0.000
#
#     Neutral  Positive  polarity  subjectivity  ...  upper_case_word_count  \
# 36    0.723     0.277  0.505273      0.704909  ...                      0
# 48    0.725     0.275  0.362500      0.731250  ...                      0
# 60    0.592     0.408  0.671667      0.756667  ...                      0
# 72    0.757     0.212  0.384091      0.638636  ...                      2
# 84    0.806     0.194  0.307273      0.579242  ...                      2
#
#     stopword_count  noun_count  verb_count  adj_count  adv_count  pron_count  \
# 36              12           8           6          6          5           4
# 48              18          14           6          6          2           5
# 60               6           5           6          4          1           2
# 72              15          12           6          5          0           3
# 84              14          12           6          5          1           3
#
#                                             top_words  Price change sign long  \
# 36  [(2017, 1), (great, 1), (year, 1), (performed,...                       1
# 48  [(year, 2), (2018, 1), (outstanding, 1), (Abbo...                       1
# 60  [(growth, 2), (focus, 1), (organic, 1), (drivi...                       1
# 72  [(EPS, 2), (growth, 2), (Despite, 1), (challen...                       1
# 84  [(year, 2), (EPS, 2), (2021, 1), (outstanding,...                      -1
#
#     word_calculation
# 36          1.450746
# 48          0.627955
# 60          1.113614
# 72          0.222914
# 84          1.858078
#
# [5 rows x 26 columns]
